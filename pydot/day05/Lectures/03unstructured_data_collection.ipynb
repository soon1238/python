# %% [markdown]
# # Collecting unstructured data with webscraping from lazada.sg

# %% [markdown]
# * Let's try web scraping the "computers-laptops" category from lazada.sg (http://www.lazada.sg/shop-computers-laptops/).
# * Our goal is to get the product links related to "computers-laptop".
# * Set the main_url and category to appropriate level in main. We will start from scraping the very first page only.
# * Start by installing necessary libraries.

# %%
import requests # Downloads files and web pages from the Internet.
from bs4 import BeautifulSoup # Parses HTML, the format that web pages are written in.
import csv

# %% [markdown]
# **More about libraries..**
#
# ** <font color = green>Request</font> **
#
# The first thing we’ll need to do to scrape a web page is to download the page. We can download pages using the Python requests library. The requests library will make a GET request to a web server, which will download the HTML contents of a given web page for us. There are several different types of requests we can make using requests, of which GET is just one.
#
# ** <font color=green>Beautiful Soup</font>**
#
# After downloading HTML document using request, We can use the BeautifulSoup library to parse this document, and extract the text from the p tag. We first have to import the library, and create an instance of the BeautifulSoup class to parse our document:

# %% [markdown]
# * The function "get_product_links_from_categories()" will extract the data.

# %% [markdown]
# * Now we have got all the links inside the appropriate class.
# * It's time to validate the product information and filter it out.

# %%
def product_info(product_url):
    '''
    identifies various needed information per product to put into store_product function: 
    [id, name, details, rating, store, price, discount, img_url, comments]
    :param product_url: url to product
    '''
    soup = BeautifulSoup(requests.get(product_url).text, "html.parser")
    print('from: ' + product_url)
    
    # Get product ID
    id = product_url.split('-')[-1][:-18] # index values (0 ~ -1, 0 ~ -18) will extract unique product ID
    
    # Get product name
    name = soup.find('h1').string.strip() 
    # strip() removes all whitespace at the start and end, including spaces, tabs, newlines and carriage returns. 
    
    # Get product details
    details = ""
    for bullet in soup.find('ul', {'class': 'prd-attributesList ui-listBulleted js-short-description'}).findAll('span'):
        # if there is a string
        if bullet.string:
            details += "--" + bullet.string # Concatenate all details with "--"
            
    # Get product rating
    rating = soup.findAll('div', {'class': 'product-card__rating__stars'})
    if len(rating) != 0:
        rating = int(str(rating[0].findAll('div')[1].get('style')).split()[-1][:-1])
    else:
        rating = 0
    
    # Get store info
    store = soup.findAll('a', {'class': 'product-fulfillment__item__link product__seller__name__anchor'})
    # when SOLD & FULFILLED BY Lazada no store link
    if len(store) == 0:
        store = 'Lazada'
    else:
        store = store[0].find('span').string.strip()
        
    # Get product price
    price = float(soup.find('span', {'id':'product_price'}).string)
    
    # Get product discount
    discount = soup.findAll('span', {'id': 'product_saving_percentage'})
    if len(discount) != 0:
        discount = float(discount[0].string[:-1])
    else:
        discount = 0
        
    # Get product image
    img_url = soup.findAll('img', {'class' : 'itm-img'})[-1].get('src')
    
    print name
    print rating
    data = [id, name, details, rating, store, price, discount, img_url]
    # Store data into the product table, returns True if successful
    csv_writer(data)
    return

# %% [markdown]
# * Now let's go through what needs to be done in get_product_links_from_categories().
# * For further extension in data collection, we will leave arguments in general form: (category_url, main_url, num_pages).

# %%
def get_product_links_from_categories(category_url, main_url, num_pages):
    '''
     goes through each category and finds product_url to put into per product function
    :param category_url: eg. 'http://lazada.sg/shop-category/?page='
    :param num_pages: number of pages to go through per category
    '''
    for i in range(1,num_pages+1):

        soup = BeautifulSoup(requests.get(category_url+str(i)).text, "html.parser")
        # The findAll method traverses the tree, starting at the given point, 
        # and finds all the Tag and NavigableString objects that match the criteria you give. 
        # Note that findAll returns a list, so we’ll have to loop through, or use list indexing, it to extract text.
        # We should go with option soup.a and it should return the links available in the web page.
        # To show only links, we need to iterate over each a tag and then return the link using attribute “href” with get.
        # Note href attribute specifies the URL of the page the link goes to.
        
        for link in soup.findAll('a', {'class': 'c-product-card__name'}):
            href = main_url + link.get('href')
            product_info(href)
    return

# %% [markdown]
# ## Store data in CSV. file

# %%
def csv_writer(line):
    # write data to a CSV file path
    with open("result.csv","a") as csv_file:
        writer = csv.writer(csv_file, delimiter=',')
        writer.writerow([unicode(s).encode("utf-8") for s in line])

# %% [markdown]
# ## <font color = red> main </font>

# %%
if __name__ == "__main__":
    main_url = 'http://www.lazada.sg'
    category = 'computers-laptops'
    cat_url = main_url + '/shop-' + category + '/?page='    
    get_product_links_from_categories(cat_url, main_url, 1)
    print("") #output not shown as it is too long.

# %% [markdown]
# ## Cursory check about the output using pandas

# %% [markdown]
# ### What is Pandas?
# pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language. It is already well on its way toward this goal.

# %%
import pandas as pd
df1 = pd.read_csv("result.csv")
print(df1) #output not shown as it is too long.
# Out:
#       8458787       Xiaomi Mi Notebook Air 13.3″ Silver (EXPORT)  \
# 0    17867726                        Lenovo ideapad 310 (Silver)
# 1    17867705                       Lenovo ideapad 100S (Silver)
# 2    19158272  GIGABYTE GeForce® GTX 1080 Ti Gaming OC 11GB DDR5
# 3    11130118                   Dell SE2417HG 24" Gaming Monitor
# 4    11108646  WD MY Book 4TB Desktop External Hard Drive (WD...
# 5    10034952  Seagate Backup Plus Slim 2TB Portable External...
# 6    16667718  Microsoft Office 2016 Professional Plus Digita...
# 7    17867729                        Lenovo ideapad 310 (Silver)
# 8    17867727                          Lenovo ideapad 100S (Red)
# 9    20355376  New Asus Zenbook ROSE GOLD UX330CA-FC045T (Int...
# 10   17598325  Acer Aspire V13 Hello Kitty Limited Edition La...
# 11    7954758                           WD RED 4TB NAS Hard Disk
# 12   12945473  SanDisk iXpand Mini Flash Drive 32GB USB3.0 fo...
# 13   14498643  LZX EVOLVE S3 Gaming Desktop (i5-8G-1T-N1060-W...
# 14   20499363  Logitech G102 Optical Gaming Mouse (Online Exc...
# 15   17867737          Lenovo ideacentre610S (Without Projector)
# 16   19264615  ROG Strix GeForce GTX 1080 Ti OC edition 11GB ...
# 17   17953502                    Logitech MK710 Wireless Desktop
# 18   18678006                              Lenovo Yoga 510 Black
# 19   17953501      LENOVO UHD F309 USB 3.0 Grey External 2TB HDD
# 20    2573740  HP Printer 2130 Color All in One Print Scan Co...
# 21    4057055           Dell U2417H 24" InfinityEdge IPS Monitor
# 22   17898694  AMD RYZEN 7 1700X 8-Core 3.4 GHz (3.8 GHz Turb...
# 23    7697972  Microsoft Office 2016 Home and Business (1 PC)...
# 24   17628944  USB Flash Drive Memory USB Stick U Disk Pen Dr...
# 25   11416668    Logitech Wireless Mouse M275 (Online Exclusive)
# 26   17953503  Toshiba 1TB Canvio Ready Portable HDD - Black ...
# 27   19839325  Dell Inspiron 14''-5459 Business Class Noteboo...
# 28    9196645  HP 7th Gen15.6" Intel Core i5 8GB RAM Graphic ...
# 29    3346122    Acer Predator X34 QHD IPS G-Sync Gaming Monitor
# ..        ...                                                ...
# 113  10824862                        ASUS Vivobook K401UQ-FA075T
# 114   2660098              Sandisk Cruzer Blade Flash Drive 16GB
# 115  28202788  Hot Sell 2TB USB Flash Drive Memory USB Stick ...
# 116  26598142                              Lenovo Yoga 510 Black
# 117  26598149                        ASUS Vivobook K401UQ-FA074T
# 118  26598154                        Lenovo ideapad 310 (Silver)
# 119   3000154        TP-LINK - RE200, AC750 Wi-Fi Range Extender
# 120  28882111                 Lenovo ideapad 110 (BLACK) 15.6 HD
# 121  16299123              HGST DESKSTAR 8TB NAS Hard Disk (8TB)
# 122   4057055           Dell U2417H 24" InfinityEdge IPS Monitor
# 123   3242227  Alienware 15 Gaming Laptop (6th Gen) (GTX965M)...
# 124  29903053  Acer Aspire 1 A114-31-C5Z2 Laptop - 14" HD LED...
# 125   7159980      Ultrathin Foldable 2.4G Wireless Mouse (Grey)
# 126  27069921  Acer Aspire AC22-760 (i61041T) - 21.5"/i3-6100...
# 127  16298771                       Acer KA271 27-inches Monitor
# 128  10692444  Xiaomi Air Notebook 12.5 inch 4GB RAM 128GB (E...
# 129  26598137                       Lenovo ideapad 110S (Silver)
# 130  10027618                          Logitech M331 Silent Plus
# 131  10117261  Seagate Backup Plus Slim 1TB Portable External...
# 132  26543616                      Logitech MK345 Wireless Combo
# 133  10034952  Seagate Backup Plus Slim 2TB Portable External...
# 134  13113067     Logitech MX Anywhere 2 - Wireless Mobile Mouse
# 135  11416667  Logitech MK240 Wireless Compact Keyboard and M...
# 136  33703471  Acer KG271A Gaming Monitor with 144Hz Refresh ...
# 137   9296218  HP Printer 3630 Wireless Print Scan Copy Wifi ...
# 138   7751641               HP DJ3630 All In One Deskjet Printer
# 139   6760795  SanDisk Ultra Flair 32GB USB 3.0 Flash Drive (...
# 140    372126       Logitech G402 Hyperion Fury FPS Gaming Mouse
# 141   9270096                  HP 27inch IPS Full HD LED Monitor
# 142  14548430  Acer Aspire ES11 (ES1-132-C0CP) 11.6" Ultrathi...
#
#     --Slim all-metal body--Full HD screen--Ultra-narrow borders--Long battery life — 9.5 hours-- Intel Core i5 processor--NVIDIA 940MX graphics card--1GB GDDR5--8 GB DDR4 RAM--256GB SSD PCIe  \
# 0    --IdeaPad 310-14IKB: 14.0 FHD TN GL(SLIM)--Int...
# 1    --Ideapad 100S-11IBY--11.6 HD TN GL(SLIM)--Z37...
# 2    --Powered by GeForce® GTX 1080 Ti--Integrated ...
# 3    --TN (Twisted Nematic) Panel--HDMI + VGA Input...
# 4    --4TB Capacity--USB 3.0 / USB 2.0 --Auto backu...
# 5    --200GB of free OneDrive cloud storage for 2 y...
# 6    --Provided is an OEM product activation key fo...
# 7    --IdeaPad 310-14IKB: 14.0 FHD TN GL(SLIM)--Int...
# 8    --Ideapad 100S-11IBY--11.6 HD TN GL(SLIM)--Z37...
# 9    --Panel: 13.3'' FHD LED-backlit Slim IPS (1920...
# 10   --Hello Kitty Limited Edition (Online Exclusiv...
# 11   --Fill your NAS with WD Red, then fill it with...
# 12   --Capacity: 32GB--Free up iPhone space fast wi...
# 13   --Intel® Core™ i5-7400 (Up to 3.50 GHz)--8GB D...
# 14   --200DPI to 6000DPI adjustable optical sensor-...
# 15   --IdeaCentre 610S-02ISH--INTEL PENTIUM G4400T ...
# 16   --NVIDIA GeForce® GTX 1080 Ti is the\nfastest ...
# 17   --Up to three-year battery life for both keybo...
# 18   --IdeaPad YOGA 510-14IKB: 14.0 FHD IPS AG TOUC...
# 19   --Portable Hard Drive--Capacity: 2 TB--Connect...
# 20   --Count on easy versatility. Print, scan, and ...
# 21   --World’s\nthinnest border: Create a multiple ...
# 22   --AMD SenseMI Technology--AMD XFR (eXtended Fr...
# 23   --100% Local Microsoft Singapore Distributor's...
# 24   -- Capacity:2TB --    Interface: USB 3.0 inter...
# 25   --2.4GHz wireless mouse--1000DPi sensor--25m w...
# 26   --2.5 external hard drive--USB 3.0 (USB 2.0 Co...
# 27   --Intel Core i76500U--1TB SATA HDD--NVIDIA® Ge...
# 28   --\u003Cul\u003E \u003Cli\u003ENew 7th Generat...
# 29   --34" Ultrawide QHD (3440x1440)--IPS 4ms respo...
# ..                                                 ...
# 113  --Thin and light design\nPowerful Intel Core p...
# 114  --Ultra-compact and portable contoured styling...
# 115  --Capacity:2TB -- Interface: USB 3.0\ninterfac...
# 116  --IdeaPad 310-14IKB: 14.0 FHD TN GL(SLIM)--Int...
# 117  --Thin and light design\nPowerful Intel Core p...
# 118  --IdeaPad 310-14IKB: 14.0 FHD TN GL(SLIM)--Int...
# 119  --Boosts wireless signal to previously unreach...
# 120  --IdeaPad 110-15ACL: 15.6 HD TN GL(SLIM)--AMD ...
# 121  --High-Performance HDD For Desktop NAS Systems...
# 122  --World’s thinnest border: Create a multiple s...
# 123  --Intel i7-6700HQ--8GB DDR4 RAM--1TB HDD--Nvid...
# 124  --Intel® Celeron® dual-core processor N3350--1...
# 125  --Key number: 3 Optical--Resolution: 1000dpi--...
# 126  --21.5” FHD--Intel® Core™ i3-6100U--Windows® 1...
# 127  --See clearly with a beautiful Full HD display...
# 128  --\u003Cdiv\u003E\u003Cul\u003E\u003Cli\u003E\...
# 129  --IdeaPad 110S-11IBR: 11.6 HD TN AG (SLIM)--IN...
# 130  --ENJOY THE SOUND OF SILENCE--CRAFTED FOR YOUR...
# 131  -- --Create easy customized backup plans with ...
# 132  --Wireless Mouse and Keyboard Combo--Comfortab...
# 133  --Create easy customized backup plans with inc...
# 134  --Tracks virtually anywhere--Compact, sculpted...
# 135  --36-month battery life--Adjustable keyboard h...
# 136  --27” (16:9) Full HD Display (TN Panel)--1ms H...
# 137  --All in one printing device (Printer, Copier,...
# 138  --All in one printing device (Printer, Copier,...
# 139  --5-year limited warranty--Transfer Speeds Up ...
# 140  --Fusion Engine hybrid sensor--8 programmable ...
# 141  --Ultra thin design--Edge to edge design deliv...
# 142  --11.6" Ultrathin--Intel Celeron Processor N33...
#
#       77  Lazada   1046.0  30.0  \
# 0      0  Lazada   899.00  10.0
# 1      0  Lazada   299.00   9.0
# 2      0  Lazada  1148.00   9.0
# 3      0  Lazada   156.00  48.0
# 4    100  Lazada   189.00  53.0
