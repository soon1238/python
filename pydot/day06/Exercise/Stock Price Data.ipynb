# %%
# Install Python Yahoo Finance
# pip install yahoo-finance
from yahoo_finance import Share
yahoo = Share('YHOO')
print dir(yahoo)
# Out:
# ['__class__', '__delattr__', '__dict__', '__doc__', '__format__', '__getattribute__', '__hash__', '__init__', '__module__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_change_incorrect_none', '_fetch', '_is_error_in_results', '_key', '_prepare_query', '_request', '_table', 'data_set', 'get_200day_moving_avg', 'get_50day_moving_avg', 'get_EPS_estimate_current_year', 'get_EPS_estimate_next_quarter', 'get_EPS_estimate_next_year', 'get_avg_daily_volume', 'get_book_value', 'get_change', 'get_change_from_200_day_moving_average', 'get_change_from_50_day_moving_average', 'get_change_from_year_high', 'get_change_from_year_low', 'get_change_percent_change', 'get_currency', 'get_days_high', 'get_days_low', 'get_days_range', 'get_dividend_pay_date', 'get_dividend_share', 'get_dividend_yield', 'get_earnings_share', 'get_ebitda', 'get_ex_dividend_date', 'get_historical', 'get_last_trade_with_time', 'get_market_cap', 'get_name', 'get_one_yr_target_price', 'get_open', 'get_percent_change', 'get_percent_change_from_200_day_moving_average', 'get_percent_change_from_50_day_moving_average', 'get_percent_change_from_year_high', 'get_percent_change_from_year_low', 'get_prev_close', 'get_price', 'get_price_EPS_estimate_current_year', 'get_price_EPS_estimate_next_year', 'get_price_book', 'get_price_earnings_growth_ratio', 'get_price_earnings_ratio', 'get_price_sales', 'get_short_ratio', 'get_stock_exchange', 'get_trade_datetime', 'get_volume', 'get_year_high', 'get_year_low', 'get_year_range', 'refresh', 'symbol']

# %%
import pandas
df = pandas.read_csv('stocks.csv')
print df
# Out:
#      Symbol                                     Name LastSale     MarketCap  \
# 0      PCYG                    Park City Group, Inc.     12.6  2.446027e+08
# 1      PSTB                Park Sterling Corporation   11.585  6.163279e+08
# 2      PKBK                      Parke Bancorp, Inc.    20.95  1.587446e+08
# 3      PRKR                       ParkerVision, Inc.     2.07  3.663465e+07
# 4      PKOH                 Park-Ohio Holdings Corp.    36.25  4.552346e+08
# 5      PTNR      Partner Communications Company Ltd.     5.16  3.035508e+07
# 6      PBHC                 Pathfinder Bancorp, Inc.   15.485  6.600791e+07
# 7      PATK                 Patrick Industries, Inc.       65  1.089662e+09
# 8      PNBK            Patriot National Bancorp Inc.     16.5  6.425311e+07
# 9      PATI     Patriot Transportation Holding, Inc.     19.1  6.310262e+07
# 10     PEGI                Pattern Energy Group Inc.   22.865  2.005894e+09
# 11     PDCO                Patterson Companies, Inc.    43.93  4.267097e+09
# 12     PTEN               Patterson-UTI Energy, Inc.    21.53  4.563791e+09
# 13     PAVM                              PAVmed Inc.      3.7  4.932548e+07
# 14    PAVMW                              PAVmed Inc.      1.4  0.000000e+00
# 15     PAYX                            Paychex, Inc.    59.28  2.129624e+10
# 16     PCTY            Paylocity Holding Corporation    47.16  2.429230e+09
# 17     PYDS               Payment Data Systems, Inc.     1.36  1.608832e+07
# 18     PYPL                    PayPal Holdings, Inc.    51.19  6.149242e+10
# 19     PBBI                         PB Bancorp, Inc.    10.35  8.105260e+07
# 20     CNXN                      PC Connection, Inc.    26.34  7.048867e+08
# 1001                             Other Specialty Stores
# 1002                                Investment Managers
# 1003                    Industrial Machinery/Components
# 1004                                  Business Services
# 1005                                  Business Services
# 1006                               Oil & Gas Production
# 1007                               Oil & Gas Production
# 1008                                        Major Banks
# 1009                                        Major Banks
# 1010                                        Major Banks
# 1011                              Major Pharmaceuticals
# 1012                                       EDP Services
# 1013                              Major Pharmaceuticals
# 1014                              Major Pharmaceuticals
# 1015                     Clothing/Shoe/Accessory Stores
# 1016                              Major Pharmaceuticals
# 1017                                       EDP Services
#
#                                 Industry  Summary Quote
# 0      http://www.nasdaq.com/symbol/pcyg            NaN
# 1      http://www.nasdaq.com/symbol/pstb            NaN
# 2      http://www.nasdaq.com/symbol/pkbk            NaN
# 3      http://www.nasdaq.com/symbol/prkr            NaN
# 4      http://www.nasdaq.com/symbol/pkoh            NaN
# 5      http://www.nasdaq.com/symbol/ptnr            NaN
# 6      http://www.nasdaq.com/symbol/pbhc            NaN
# 7      http://www.nasdaq.com/symbol/patk            NaN
# 8      http://www.nasdaq.com/symbol/pnbk            NaN
# 9      http://www.nasdaq.com/symbol/pati            NaN
# 10     http://www.nasdaq.com/symbol/pegi            NaN
# 11     http://www.nasdaq.com/symbol/pdco            NaN
# 12     http://www.nasdaq.com/symbol/pten            NaN
# 13     http://www.nasdaq.com/symbol/pavm            NaN
# 14    http://www.nasdaq.com/symbol/pavmw            NaN
# 15     http://www.nasdaq.com/symbol/payx            NaN
# 16     http://www.nasdaq.com/symbol/pcty            NaN
# 17     http://www.nasdaq.com/symbol/pyds            NaN
# 18     http://www.nasdaq.com/symbol/pypl            NaN
# 19     http://www.nasdaq.com/symbol/pbbi            NaN
# 20     http://www.nasdaq.com/symbol/cnxn            NaN
# 21     http://www.nasdaq.com/symbol/pcmi            NaN
# 22     http://www.nasdaq.com/symbol/pcsb            NaN
# 23     http://www.nasdaq.com/symbol/pcti            NaN
# 24     http://www.nasdaq.com/symbol/pdce            NaN
# 25     http://www.nasdaq.com/symbol/pdfs            NaN
# 26     http://www.nasdaq.com/symbol/pdli            NaN
# 27     http://www.nasdaq.com/symbol/pdvw            NaN
# 28     http://www.nasdaq.com/symbol/skis            NaN
# 29      http://www.nasdaq.com/symbol/pgc            NaN
# ...                                  ...            ...
# 988    http://www.nasdaq.com/symbol/xplr            NaN
# 989    http://www.nasdaq.com/symbol/xtlb            NaN
# 990    http://www.nasdaq.com/symbol/xnet            NaN
# 991    http://www.nasdaq.com/symbol/yhoo            NaN
# 992    http://www.nasdaq.com/symbol/yndx            NaN
# 993    http://www.nasdaq.com/symbol/yerr            NaN
# 994    http://www.nasdaq.com/symbol/ytra            NaN
# 995    http://www.nasdaq.com/symbol/yten            NaN
# 996     http://www.nasdaq.com/symbol/yin            NaN
# 997    http://www.nasdaq.com/symbol/yrcw            NaN
# 998    http://www.nasdaq.com/symbol/yeco            NaN
# 999      http://www.nasdaq.com/symbol/yy            NaN
# 1000   http://www.nasdaq.com/symbol/zfgn            NaN
# 1001   http://www.nasdaq.com/symbol/zagg            NaN
# 1002   http://www.nasdaq.com/symbol/zais            NaN
# 1003   http://www.nasdaq.com/symbol/zbra            NaN
# 1004      http://www.nasdaq.com/symbol/z            NaN
# 1005     http://www.nasdaq.com/symbol/zg            NaN
# 1006     http://www.nasdaq.com/symbol/zn            NaN
# 1007  http://www.nasdaq.com/symbol/znwaa            NaN
# 1008   http://www.nasdaq.com/symbol/zion            NaN
# 1009  http://www.nasdaq.com/symbol/zionw            NaN
# 1010  http://www.nasdaq.com/symbol/zionz            NaN
# 1011   http://www.nasdaq.com/symbol/ziop            NaN
# 1012   http://www.nasdaq.com/symbol/zixi            NaN
# 1013   http://www.nasdaq.com/symbol/zgnx            NaN
# 1014   http://www.nasdaq.com/symbol/zsan            NaN
# 1015   http://www.nasdaq.com/symbol/zumz            NaN
# 1016   http://www.nasdaq.com/symbol/zyne            NaN
# 1017   http://www.nasdaq.com/symbol/znga            NaN
#
# [1018 rows x 10 columns]

# %%
symbols = df['PCYG']

# %%
for s in symbols:
    stock = Share(s)
    print stock.get_open()
# Out:
# 11.57
# 21.15
# 2.04
# 35.80
# 5.13
# 15.332
# 67.45
# None
# 19.01
# 22.99
# 44.80
# 21.07
# 3.50
# 1.55
# 59.22
# 46.45
# 1.34
# 51.04
# 10.40
# 26.97
# 19.95
# 16.74
# 6.42
# 51.74
# 16.59
# 2.33
# 22.90
# 4.55
# 30.15
# 56.60
# 6.18
# 19.83
# 43.79
# 14.15
# 7.51
# 39.97
# 19.90
# 30.89
# 26.00
# 13.30
# 40.49
# 16.79
# 28.36
# 25.80
# 7.64
# 0.568
# 22.25
# 17.59
# 2.26
# 1.380
# 1.68
# YQLResponseMalformedErrorTraceback (most recent call last)
# <ipython-input-11-0f3b9e548706> in <module>()
#       1 for s in symbols:
# ----> 2     stock = Share(s)
#       3     print stock.get_open()
#
# /usr/local/lib/python2.7/dist-packages/yahoo_finance/__init__.pyc in __init__(self, symbol)
#     176         self._table = 'quotes'
#     177         self._key = 'symbol'
# --> 178         self.refresh()
#     179
#     180     def _fetch(self):
#
# /usr/local/lib/python2.7/dist-packages/yahoo_finance/__init__.pyc in refresh(self)
#     140
#     141         """
# --> 142         self.data_set = self._fetch()
#     143
#     144
#
# /usr/local/lib/python2.7/dist-packages/yahoo_finance/__init__.pyc in _fetch(self)
#     179
#     180     def _fetch(self):
# --> 181         data = super(Share, self)._fetch()
#     182         if data['LastTradeDate'] and data['LastTradeTime']:
#     183             data[u'LastTradeDateTimeUTC'] = edt_to_utc('{0} {1}'.format(data['LastTradeDate'], data['LastTradeTime']))
#
# /usr/local/lib/python2.7/dist-packages/yahoo_finance/__init__.pyc in _fetch(self)
#     132     def _fetch(self):
#     133         query = self._prepare_query(table=self._table, key=self._key)
# --> 134         data = self._request(query)
#     135         return data
#     136
#
# /usr/local/lib/python2.7/dist-packages/yahoo_finance/__init__.pyc in _request(self, query)
#     123                 raise YQLQueryError(response['error']['description'])
#     124             except KeyError:
# --> 125                 raise YQLResponseMalformedError()
#     126         else:
#     127             if self._is_error_in_results(results):
#
# YQLResponseMalformedError: Response malformed.
