# %%
f=open("months.txt","r")
print type (f)
file_content=f.read()
print(type(file_content))
print(file_content)
f.close()
# Out:
# <type 'file'>
# <type 'str'>
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
f.name
# Out:
# 'months.txt'

# %%
help(f)
# Out:
# Help on file object:
#
# class file(object)
#  |  file(name[, mode[, buffering]]) -> file object
#  |
#  |  Open a file.  The mode can be 'r', 'w' or 'a' for reading (default),
#  |  writing or appending.  The file will be created if it doesn't exist
#  |  when opened for writing or appending; it will be truncated when
#  |  opened for writing.  Add a 'b' to the mode for binary files.
#  |  Add a '+' to the mode to allow simultaneous reading and writing.
#  |  If the buffering argument is given, 0 means unbuffered, 1 means line
#  |  buffered, and larger numbers specify the buffer size.  The preferred way
#  |  to open a file is with the builtin open() function.
#  |  Add a 'U' to mode to open the file for input with universal newline
#  |  support.  Any line ending in the input file will be seen as a '\n'
#  |  in Python.  Also, a file so opened gains the attribute 'newlines';
#  |  the value for this attribute is one of None (no newline read yet),
# ...

# %%
f.read()
# Out:
# 'January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember'

# %%
f=open("hello123.txt","w")
for i in range (10):
    f.write("Hello World %s \n" %i)

f.close()

# %%
filename="hello123.txt"
mode ="r"

fileObject = open(filename,mode)
lines_list=fileObject.readlines()
for line in lines_list:
#     print (type(line))
    print(line.strip())
# Out:
# Hello World 0
# Hello World 1
# Hello World 2
# Hello World 3
# Hello World 4
# Hello World 5
# Hello World 6
# Hello World 7
# Hello World 8
# Hello World 9

# %%
f=open("tmp.txt","w")
f.write("This is first sentence\nwelcome\n")
f.write("This is second sentence\ngood bye\n")
f.close()

# %%
# !cat tmp.txt
# Out:
# This is first sentence
# welcome
# This is second sentence
# good bye

# %%
filename="hello123.txt"
mode="r"
fileObject=open (filename,mode)
for line in fileObject:
    print line
# Out:
# Hello World 0
#
# Hello World 1
#
# Hello World 2
#
# Hello World 3
#
# Hello World 4
#
# Hello World 5
#
# Hello World 6
#
# Hello World 7
#
# Hello World 8
#
# Hello World 9

# %%
f=open("months.txt","r")
for line in f:
    line=line.strip();
    if (line.endswith("h")):
    #if (line.find("er")>1):
        print line
f.close()
# Out:
# March

# %%
help(str)
# Out:
# Help on class str in module __builtin__:
#
# class str(basestring)
#  |  str(object='') -> string
#  |
#  |  Return a nice string representation of the object.
#  |  If the argument is a string, the return value is the same object.
#  |
#  |  Method resolution order:
#  |      str
#  |      basestring
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(...)
#  |      x.__add__(y) <==> x+y
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> string
#  |
#  |      Return a formatted version of S as described by format_spec.
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getnewargs__(...)
#  |
#  |  __getslice__(...)
#  |      x.__getslice__(i, j) <==> x[i:j]
#  |
# ...

# %%
for i in range(10):
    with open("temp.txt","a") as f:
        f.write("%s \n" %i)

# %%
import csv
with open ("quiz.csv","wb") as csvfile:
    csv_writer =csv.writer(csvfile,delimiter=",")
    headers = ["s/no", "questions_name"]
    csv_writer.writerow(headers)
    ques=["How are","How old are you"]
    for index,qu in enumerate  (ques):
        csv_writer.writerow([index,qu])

# %%
import csv
with open ("dict_quiz.csv","wb") as csvfile:
    headers = ["s/no", "questions_name"]
    dict_writer =csv.DictWriter(csvfile,delimiter=",",fieldnames=headers)
    dict_writer.writeheader()
#     csvwriter.writerow(headers)
    ques=["How are you?","How old are you?"]
    for index,qu in enumerate  (ques):
        print index
        print qu
        dict_writer.writerow({headers[0]:index,headers[1]:qu})
# Out:
# 0
# How are you?
# 1
# How old are you?

# %%
survey_qns = {
       'Q1x':{
           'Question' : 'Q1',
           'Response' : 'Yes',            
       },
       'Q2x':{
           'Question'  : 'Q2',
           'Response'  : 'Yes',
       }
}
qns = survey_qns.items()
print qns
for q,v in qns:
    print q,v


for q,v in survey_qns.iteritems():
    print q
    print v
# Out:
# [('Q2x', {'Question': 'Q2', 'Response': 'Yes'}), ('Q1x', {'Question': 'Q1', 'Response': 'Yes'})]
# Q2x {'Question': 'Q2', 'Response': 'Yes'}
# Q1x {'Question': 'Q1', 'Response': 'Yes'}
# Q2x
# {'Question': 'Q2', 'Response': 'Yes'}
# Q1x
# {'Question': 'Q1', 'Response': 'Yes'}

# %%
import psutil
print (psutil.cpu_percent())
print(psutil.virtual_memory().percent())
# Out:
# 6.7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-3ae07ba9c8bb> in <module>()
#       1 import psutil
#       2 print (psutil.cpu_percent())
# ----> 3 print(psutil.virtual_memory().percent())
#
# TypeError: 'float' object is not callable

# %%
#homework
import csv
import time
from datetime import datetime
import psutil
with open ("usage.csv","wb") as csvfile: #change mode to 'at' for append
    csv_writer =csv.writer(csvfile,delimiter=",")
    headers = ["utc", "local d/t","cpu%",'memory%']
    csv_writer.writerow(headers)
    count=5
    while (count>0):
        cpu=psutil.cpu_percent()
        print (cpu)
        vm=psutil.virtual_memory().percent
        print (vm)
        unix_t=time.time()
        print (unix_t)
        current_time=datetime.now()
        print current_time
#     print (time.mktime(current_time.timetuple())) #unix time as as time.time()
        csv_writer.writerow([unix_t,current_time,cpu,vm])
        time.sleep(5)
        count-=1
# Out:
# 2.7
# 59.1
# 1508340997.69
# 2017-10-18 23:36:37.694882
# 2.0
# 59.8
# 1508340999.7
# 2017-10-18 23:36:39.700981
# 0.9
# 59.8
# 1508341001.71
# 2017-10-18 23:36:41.707009
# 3.6
# 59.3
# 1508341003.71
# 2017-10-18 23:36:43.707707
# 6.9
# 59.3
# 1508341005.71
# 2017-10-18 23:36:45.712869

# %%
'''
1. Run a program every 5 seconds
2. Use psutil to collect metrics about CPU & memory
3. Write the metrics into a csv. file
'''
import time
import psutil
import csv
import datetime
from pymongo import MongoClient
filename = "cpu_mem.csv"
dbuser="python"
dbpassword="password"
dbname="pythonapp"
# mongodb://%s:%s@ds125555.mlab.com:25555/%s
my_mongo_db_uri = "mongodb://%s:%s@ds125555.mlab.com:25555/%s" % (dbuser,dbpassword,dbname)
client =MongoClient(my_mongo_db_uri)
db=client.get_database()

def write_to_mongodb( sno, cpu, mem , date):
#     print(db.name)
#     collection=db['dummy_collection']
#     cursor = collection.find({})
#     for document in cursor:
#         print(document)    
    db.Metrics.insert_one({"id":sno,"cpu":cpu,"mem":mem,"date":date})


def write_header_to_a_csv_file():
    with open(filename, "ab") as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(["sno","cpu","mem","date"])


def write_to_csv(sno,cpu, mem, date):
    print (cpu,mem,date)
    with open(filename, "ab") as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow([sno,cpu,mem,date])

def task_to_be_executed(index):
    cpu,mem = collect_cpu_mem_metrics()
    date = datetime.datetime.now()
    date = str(date)[:19]
    write_to_csv( index, cpu, mem , date )
    write_to_mongodb( index, cpu, mem , date)
    

def run_something_every_x_seconds(seconds):
    index = 1
    while (True):
        """
        Every x second block
        """
        print ("Running every %s Seconds" %seconds )
        # function to be executed, every x seconds
        task_to_be_executed(index)
        index += 1
        time.sleep( seconds )


def collect_cpu_mem_metrics():
    cpu_percent = psutil.cpu_percent()
    mem_percent = psutil.virtual_memory().percent
    return (cpu_percent, mem_percent)

write_header_to_a_csv_file()
run_something_every_x_seconds(5)
# Out:
# Running every 5 Seconds
# (3.1, 63.9, '2017-10-19 21:20:13')
# Running every 5 Seconds
# (1.9, 63.8, '2017-10-19 21:20:23')
# Running every 5 Seconds
# (1.1, 64.2, '2017-10-19 21:20:28')
# Running every 5 Seconds
# (2.4, 63.8, '2017-10-19 21:20:34')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-104078ad76d2> in <module>()
#      66
#      67 write_header_to_a_csv_file()
# ---> 68 run_something_every_x_seconds(5)
#      69
#      70
#
# <ipython-input-11-104078ad76d2> in run_something_every_x_seconds(seconds)
#      57         task_to_be_executed(index)
#      58         index += 1
# ---> 59         time.sleep( seconds )
#      60
#      61
#
# KeyboardInterrupt:

# %%
dbuser="python"
dbpassword="password"
dbname="pythonapp"
# mongodb://%s:%s@ds125555.mlab.com:25555/%s
my_mongo_db_uri = "mongodb://%s:%s@ds125555.mlab.com:25555/%s" % (dbuser,dbpassword,dbname)

# %%
# !pip install pymongo
# Out:
# ...
#     100% |████████████████████████████████| 276kB 1.7MB/s ta 0:00:011
# ...

# %%
from pymongo import MongoClient
dbuser="python"
dbpassword="password"
dbname="pythonapp"
# mongodb://%s:%s@ds125555.mlab.com:25555/%s
my_mongo_db_uri = "mongodb://%s:%s@ds125555.mlab.com:25555/%s" % (dbuser,dbpassword,dbname)
client =MongoClient(my_mongo_db_uri)
db=client.get_database()
print(db.name)
collection=db['dummy_collection']
cursor = collection.find({})
for document in cursor:
    print(document)
# Out:
# pythonapp
# {u'age': 99, u'_id': ObjectId('59e89c9bf36d280364365ae7'), u'name': u'soon'}
# {u'age': 109, u'_id': ObjectId('59e8a218f36d280364365dd5'), u'name': u'Tom'}

# %%
try:
    a=10/0
    print(a)
    print ("Hello World")
except:
    print ("Error encountered!")
finally:
    print ("print anyway!")
