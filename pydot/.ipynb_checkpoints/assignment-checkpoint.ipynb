# %%
import time
import requests
#generic routine for capturing data_api from data.gov.sg
#make changes to URL and filename only

from pprint import pprint
import csv
headers=[]
off = 10
lim = 10
total=0

# filename="data.csv"
# url = "https://data.gov.sg/api/action/datastore_search?offset=%s&limit=%s&resource_id=f9dbfc75-a2dc-42af-9f50-425e4107ae84"
filename="jobs.csv"
url = "https://data.gov.sg/api/action/datastore_search?offset=%s&limit=%s&resource_id=34b5dc65-4a44-4fee-9431-7131c347f9cf"
def collectdata(url):
    custom_header = {
        "user-agent" : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36"
    }
    content = requests.get(url).json()
    return content

def write_csv_headers_and_get_total():
#   perform a read to get headers
    current_url=url %(0,10)
    content = collectdata(current_url)
    global total
    total=content.get("result").get("total")
    with open (filename,"wb") as csvfile: #change mode to 'at' for append
        csv_writer =csv.writer(csvfile,delimiter=",")
        fields=content.get("result").get("fields")
        for field in fields:
            header=field.get("id")
            headers.append(header)
        print headers
        csv_writer.writerow(headers)
        
def write_records(total):
    for i in range(0,total,off):
        current_url = url % (i,lim)
        print current_url
        content = collectdata(current_url)
#        pprint(content)
# get the records
        records=content.get("result").get("records")
#        field_name = (records[0].keys()) # using this will not return fields in correct order
#        pprint (field_name)
#     pprint (records)
        for record in records:
            record_array=[]
            for key in headers:
                record_array.append(record.get(key))
#         print(record.get(headers[0]),record.get(headers[1]),record.get(headers[2]),record.get(headers[3]))
            print record_array
            with open (filename,"ab") as csvfile: #change mode to 'at' for append
                csv_writer =csv.writer(csvfile,delimiter=",")
                csv_writer.writerow(record_array)
        time.sleep(2)
        

        
write_csv_headers_and_get_total()
print total
write_records(total)
# Out:
# [u'_id', u'year', u'job_vacancy_rate']
# 25
# https://data.gov.sg/api/action/datastore_search?offset=0&limit=10&resource_id=34b5dc65-4a44-4fee-9431-7131c347f9cf
# {u'help': u'https://data.gov.sg/api/3/action/help_show?name=datastore_search',
#  u'result': {u'_links': {u'next': u'/api/action/datastore_search?offset=10&limit=10&resource_id=34b5dc65-4a44-4fee-9431-7131c347f9cf',
#                          u'start': u'/api/action/datastore_search?limit=10&resource_id=34b5dc65-4a44-4fee-9431-7131c347f9cf'},
#              u'fields': [{u'id': u'_id', u'type': u'int4'},
#                          {u'id': u'year', u'type': u'numeric'},
#                          {u'id': u'job_vacancy_rate', u'type': u'numeric'}],
#              u'limit': 10,
#              u'offset': 0,
#              u'records': [{u'_id': 1,
#                            u'job_vacancy_rate': u'6.2',
#                            u'year': u'1990'},
#                           {u'_id': 2,
#                            u'job_vacancy_rate': u'5.2',
#                            u'year': u'1991'},
#                           {u'_id': 3,
#                            u'job_vacancy_rate': u'5',
#                            u'year': u'1992'},
#                           {u'_id': 4,
#                            u'job_vacancy_rate': u'4.8',
#                            u'year': u'1993'},
#                           {u'_id': 5,
#                            u'job_vacancy_rate': u'5.2',
#                            u'year': u'1994'},
#                           {u'_id': 6,
#                            u'job_vacancy_rate': u'5.2',
#                            u'year': u'1995'},
#                           {u'_id': 7,
#                            u'job_vacancy_rate': u'4.8',
#                            u'year': u'1996'},
#                           {u'_id': 8,
#                            u'job_vacancy_rate': u'4.3',
#                            u'year': u'1997'},
#                           {u'_id': 9,
#                            u'job_vacancy_rate': u'1.9',
#                            u'year': u'1998'},
#                           {u'_id': 10,
#                            u'job_vacancy_rate': u'2.1',
#                            u'year': u'1999'}],
#              u'resource_id': u'34b5dc65-4a44-4fee-9431-7131c347f9cf',
#              u'total': 25},
#  u'success': True}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-204a85d74653> in <module>()
#      63 write_csv_headers_and_get_total()
#      64 print total
# ---> 65 write_records(total)
#      66
#      67
#
# <ipython-input-7-204a85d74653> in write_records(total)
#      46         records=content.get("result").get("records")
#      47 #        field_name = (records[0].keys())
# ---> 48         pprint (field_name)
#      49 #     pprint (records)
#      50         for record in records:
#
# NameError: global name 'field_name' is not defined

# %%
help (headers)
# Out:
# Help on list object:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(...)
#  |      x.__add__(y) <==> x+y
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __delslice__(...)
#  |      x.__delslice__(i, j) <==> del x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getslice__(...)
#  |      x.__getslice__(i, j) <==> x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iadd__(...)
#  |      x.__iadd__(y) <==> x+=y
#  |
#  |  __imul__(...)
#  |      x.__imul__(y) <==> x*=y
#  |
#  |  __init__(...)
#  |      x.__init__(...) initializes x; see help(type(x)) for signature
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __mul__(...)
#  |      x.__mul__(n) <==> x*n
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __reversed__(...)
#  |      L.__reversed__() -- return a reverse iterator over the list
#  |
#  |  __rmul__(...)
#  |      x.__rmul__(n) <==> n*x
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __setslice__(...)
#  |      x.__setslice__(i, j, y) <==> x[i:j]=y
#  |
#  |      Use  of negative indices is not supported.
#  |
#  |  __sizeof__(...)
#  |      L.__sizeof__() -- size of L in memory, in bytes
#  |
#  |  append(...)
#  |      L.append(object) -- append object to end
#  |
#  |  count(...)
#  |      L.count(value) -> integer -- return number of occurrences of value
#  |
#  |  extend(...)
#  |      L.extend(iterable) -- extend list by appending elements from the iterable
#  |
#  |  index(...)
#  |      L.index(value, [start, [stop]]) -> integer -- return first index of value.
#  |      Raises ValueError if the value is not present.
#  |
#  |  insert(...)
#  |      L.insert(index, object) -- insert object before index
#  |
#  |  pop(...)
#  |      L.pop([index]) -> item -- remove and return item at index (default last).
#  |      Raises IndexError if list is empty or index is out of range.
#  |
#  |  remove(...)
#  |      L.remove(value) -- remove first occurrence of value.
#  |      Raises ValueError if the value is not present.
#  |
#  |  reverse(...)
#  |      L.reverse() -- reverse *IN PLACE*
#  |
#  |  sort(...)
#  |      L.sort(cmp=None, key=None, reverse=False) -- stable sort *IN PLACE*;
#  |      cmp(x, y) -> -1, 0, 1
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %%
import requests
from pprint import pprint
url = 'https://data.gov.sg/api/action/datastore_search?resource_id=f9dbfc75-a2dc-42af-9f50-425e4107ae84&limit=10&offset=0'
resp_obj = requests.get(url)
content=resp_obj.json()
#content=resp_obj.text()
#import json
#content-dic=json.loads(content)
pprint (content)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-7c62848d18c2> in <module>()
#       2 from pprint import pprint
#       3 url = 'https://data.gov.sg/api/action/datastore_search?resource_id=f9dbfc75-a2dc-42af-9f50-425e4107ae84&limit=10&offset=0'
# ----> 4 resp_obj = requests.get(url)
#       5 content=resp_obj.json()
#       6 #content=resp_obj.text()
#
# /anaconda2/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda2/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     497
#     498         settings = self.merge_environment_settings(
# --> 499             prep.url, proxies, stream, verify, cert
#     500         )
#     501
#
# /anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in merge_environment_settings(self, url, proxies, stream, verify, cert)
#     670             # Set environment's proxies.
#     671             no_proxy = proxies.get('no_proxy') if proxies is not None else None
# --> 672             env_proxies = get_environ_proxies(url, no_proxy=no_proxy)
#     673             for (k, v) in env_proxies.items():
#     674                 proxies.setdefault(k, v)
#
# /anaconda2/lib/python2.7/site-packages/requests/utils.pyc in get_environ_proxies(url, no_proxy)
#     690     :rtype: dict
#     691     """
# --> 692     if should_bypass_proxies(url, no_proxy=no_proxy):
#     693         return {}
#     694     else:
#
# /anaconda2/lib/python2.7/site-packages/requests/utils.pyc in should_bypass_proxies(url, no_proxy)
#     674     with set_environ('no_proxy', no_proxy_arg):
#     675         try:
# --> 676             bypass = proxy_bypass(netloc)
#     677         except (TypeError, socket.gaierror):
#     678             bypass = False
#
# /anaconda2/lib/python2.7/urllib.pyc in proxy_bypass(host)
#    1517             return proxy_bypass_environment(host, proxies)
#    1518         else:
# -> 1519             return proxy_bypass_macosx_sysconf(host)
#    1520
#    1521     def getproxies():
#
# /anaconda2/lib/python2.7/urllib.pyc in proxy_bypass_macosx_sysconf(host)
#    1477                 if hostIP is None:
#    1478                     try:
# -> 1479                         hostIP = socket.gethostbyname(hostonly)
#    1480                         hostIP = ip2num(hostIP)
#    1481                     except socket.error:
#
# KeyboardInterrupt:

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /anaconda2/lib/python2.7/site-packages
# Requirement already satisfied: six in /anaconda2/lib/python2.7/site-packages (from nltk)

# %%
from nltk.corpus import stopwords

filename="input.txt"

word_dict={}
# stop=set(stopwords.words('english'))

# dictionary={}
# for word in inputdata.split():
#     if dictionary.get(word,None):
#         dictionary[word]+=1
#     else:
#         dictionary[word]=1

with open(filename,"r") as f:
    content=f.read()
    content=content.lower()
    
#     bag_of_words_to_filter=()
    #cleaning
#    content=content.replace('.',"")
    
    words=content.split()
    for each_word in words:
        if each_word in word_dict:
            word_dict[each_word]+=1;
        else:
            word_dict[each_word]=1;
print (word_dict)
print (len(word_dict))
# Out:
# {'yellow': 4, 'four': 9, "friend's": 1, 'hanging': 2, 'better!': 1, 'marching': 2, 'looking': 18, 'starship?': 1, 'power...': 1, 'lord': 15, 'starship.': 7, 'starship,': 3, 'better.': 1, 'regional': 1, 'skyhoppers': 1, 'advice,': 1, 'claw-armed': 1, 'astro-droids': 2, 'foul': 1, 'fingers.': 1, 'barrage.': 1, 'screaming': 3, 'starships': 2, 'someday...': 1, 'stars.': 1, 'charter': 1, 'her.': 11, 'tired': 1, 'her!': 1, 'elegant': 2, 'second': 9, 'tensely': 1, 'thunder': 1, 'kid?': 1, "rebel's": 1, 'sights,': 2, 'conjure': 1, 'kid,': 2, 'admiral': 2, 'kid.': 8, 'crouch': 2, 'resignation.': 1, 'here
4, 'men)': 1, 'flanked': 3, 'release': 3, 'them.': 25, 'them,': 6, 'boarded': 2, 'respond': 2, 'beatup': 1, 'fair': 1, 'four-man': 1, 'dantooine': 1, 'resigned': 1, 'best': 8, 'auto-like': 1, 'countered.': 1, 'score': 1, 'pit.': 1, 'pirate': 4, 'letting': 1, 'involved.': 1, 'involved!': 1, 'spice...': 1, 'medallion': 1, 'carbon': 1, 'adventurer': 1, 'lot.': 1, 'logic': 2, 'argue': 1, 'asked': 1, 'money!': 1, '(sighing)': 1, 'money.': 3, 'canyon': 16, 'gleaming': 2, 'commands.': 2, 'humming': 2, "'nother": 1, 'startles': 1, 'chrome': 5, 'muck': 2, 'much': 16, 'deliberately': 1, 'fry': 2, 'dots': 1, 'life': 5, 'low-ceilinged': 2, 'worked': 1, 'commerce': 1, 'angry)': 1, 'artoo-detoo': 9, 'couplings.': 1, 'equator': 1, 'trees,': 1, 'eighteen': 1, 'south.': 1, 'said,': 1, 'top!': 1, 'damaged': 4, 'credit': 1, 'things': 4, 'rebellion': 9, 'haphazard': 1, 'inadvertently': 1, 'torpedoes': 1, 'marched': 1, 'idea': 1, 'thing?': 2, 'damage.': 1, 'phony.': 1, 'thing.': 4, 'echoes': 1, 'thing!': 1, 'plight': 1, 'rotates': 3, 'sandcrawler.': 3, 'rushing': 2, 'sandcrawler,': 2, 'enters': 7, 'han': 23 ...
# 5661

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /anaconda2/lib/python2.7/site-packages
# Requirement already satisfied: numpy>=1.7.1 in /anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: six>=1.10 in /anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: python-dateutil in /anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: functools32 in /anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: subprocess32 in /anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: pytz in /anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: cycler>=0.10 in /anaconda2/lib/python2.7/site-packages (from matplotlib)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /anaconda2/lib/python2.7/site-packages (from matplotlib)

# %%
#continue from above
from wordcloud import WordCloud
wc=WordCloud()
wc.generate_from_frequencies(frequencies=word_dict)
image=wc.to_image()
image.show()

# import matplotlib.pyplot as plt
# plt.imshow(wc,interpolation)

# %%
# %matplotlib inline
import mplleaflet
import geopandas as gpd
# df=gpd.read_file('/Users/tecksoon/ISS/pyCourse/pydot/singapore_roads_gen1.geojson')
admin=gpd.GeoDataFrame.from_file('/Users/tecksoon/ISS/pyCourse/pydot/SingMaps/singapore_admin.geojson')
# roads=gpd.GeoDataFrame.from_file('/Users/tecksoon/ISS/pyCourse/pydot/SingMaps/singapore_roads.geojson')
# buildings=gpd.GeoDataFrame.from_file('/Users/tecksoon/ISS/pyCourse/pydot/SingMaps/singapore_buildings.geojson')
amenities=gpd.GeoDataFrame.from_file('/Users/tecksoon/ISS/pyCourse/pydot/SingMaps/singapore_aeroways.geojson')

# amenities=gpd.GeoDataFrame.from_file('/Users/tecksoon/ISS/pyCourse/pydot/SingMaps/test1.geojson')
# amenities=gpd.GeoDataFrame.from_file('/Users/tecksoon/ISS/pyCourse/pydot/filename.geojson')
# amenities=gpd.GeoDataFrame.from_file('/Users/tecksoon/ISS/pyCourse/pydot/line.geojson')






singapore=admin.ix[0]
# roads=roads[roads.geometry.within(singapore.geometry)]
# buildings=buildings[buildings.geometry.within(singapore.geometry)]
amenities=amenities[amenities.geometry.within(singapore.geometry)]


# rx=roads.geometry.plot()
# bx=buildings.geometry.plot()
#am=amenities.geometry.plot(marker='*', color='red', markersize=200)
am=amenities.geometry.plot(color='red')

# mplleaflet.display(fig=bx.figure) #to display it right at the notebook
# mplleaflet.show(fig=bx.figure) #output as _map.html
# mplleaflet.show(fig=rx.figure)
mplleaflet.show(fig=am.figure)






# df.shape
# df.plot()
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:19: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
import csv
# Read in raw data from csv
rawData = csv.reader(open('filename.csv', 'rb'), dialect='excel')
# the template. where data from the csv will be formatted to geojson
template = \
    ''' \
    { "type" : "Feature",
        "geometry" : {
            "type" : "Point",
            "coordinates" : [%s, %s]},
        "properties" : { "id" : %s, "unixTime" : "%s", "msgtext" : "%s", "userID": "%s"}
        },
    '''
# the head of the geojson file
output = \
    ''' \
{ "type" : "Feature Collection",
    "features" : [
    '''
# loop through the csv by row skipping the first
iter = 0
for row in rawData:
    # iter += 1
    # if iter >= 2:
    id = row[2]
    lat = row[5]
    lon = row[6]
    unixTime = row[1]
    msgtext = row[3]
    userID = row[4]
    # output += template % (row[0], row[2], row[1], row[3], row[4])
    output += template % (lon, lat,  id,  unixTime, msgtext, userID)
    
# the tail of the geojson file
output += \
    ''' \
    ]
}
    '''
    
# opens an geoJSON file to write the output to
outFileHandle = open("filename.geojson", "w")
outFileHandle.write(output)
outFileHandle.close()

# %%
import csv
# Read in raw data from csv
rawData = csv.reader(open('test123.csv', 'rb'), dialect='excel')
# the template. where data from the csv will be formatted to geojson
template = \
    ''' \
    { "type" : "Feature",
        "geometry" : {
            "type" : "Point",
            "coordinates" : [%s, %s]},
        "properties" : {}
        },
    '''
# the head of the geojson file
output = \
    ''' \
{ "type" : "Feature Collection",
    "features" : [
    '''
# loop through the csv by row skipping the first
iter = 0
for row in rawData:

    lon=row[0]
    lat=row[1]
    # output += template % (row[0], row[2], row[1], row[3], row[4])
    output += template % (lon, lat)
    
# the tail of the geojson file
output += \
    ''' \
    ]
}
    '''
    
# opens an geoJSON file to write the output to
outFileHandle = open("filename.geojson", "w")
outFileHandle.write(output)
outFileHandle.close()

# %%
from firebase import firebase
firebase=firebase.FirebaseApplication ('https://ionic2do-ee1d2.firebaseio.com',None)
results=firebase.get("/task",None)
print results
for uid,items in results.iteritems():
    print uid,items, items.get("title"), items.get('status')
    for item in items:
#         print item
        print items.get(item)
#         print items.get("status")
        
#     for k,v in items.iteritems():
#         print(k+" "+v)
# Out:
#  {u'-KyEPRMnoY7sPQkMAxT7': {u'status': u'done', u'title': u'tomatoes'}, u'-KwYxXT_usFPgD4hL5jv': {u'status': u'open', u'title': u'ham'}, u'-KyEHmX68wObQHTAsmwW': {u'status': u'open', u'title': u'chillies'}, u'-KyEFMvVy3Z7g2nA8hzM': {u'status': u'done', u'title': u'instant noodle'}, u'-KyEa8f89fxV5sN9Mo0T': {u'status': u'open', u'title': u'burger'}, u'-KyEPafm25eBBRN3Jkz1': {u'status': u'open', u'title': u'onion'}, u'-KwYxWIM3NsCrLnTSloc': {u'status': u'open', u'title': u'egg'}}
# -KyEPRMnoY7sPQkMAxT7 {u'status': u'done', u'title': u'tomatoes'} tomatoes done
# done
# tomatoes
# -KwYxXT_usFPgD4hL5jv {u'status': u'open', u'title': u'ham'} ham open
# open
# ham
# -KyEHmX68wObQHTAsmwW {u'status': u'open', u'title': u'chillies'} chillies open
# open
# chillies
# -KyEFMvVy3Z7g2nA8hzM {u'status': u'done', u'title': u'instant noodle'} instant noodle done
# done
# instant noodle
# -KyEa8f89fxV5sN9Mo0T {u'status': u'open', u'title': u'burger'} burger open
# open
# burger
# -KyEPafm25eBBRN3Jkz1 {u'status': u'open', u'title': u'onion'} onion open
# open
# onion
# -KwYxWIM3NsCrLnTSloc {u'status': u'open', u'title': u'egg'} egg open
# open
# egg

# %%
import time
from datetime import date
current_date=date.today()
from firebase import firebase
firebase=firebase.FirebaseApplication ('https://ionic2do-ee1d2.firebaseio.com',None)
results=firebase.get("/location_"+str(current_date),None)
print results
for uid,items in results.iteritems():
#     print uid,items, items.get('time'), items.get('lng'),item.get('lat')
    print items.get('time'),items.get('lng'),items.get('lat')
# Out:
# {u'-KyIztIg1vfm2TALb75U': {u'lat': 1.3616946, u'lng': 103.7674774, u'time': 1510016520814}, u'-KyJ4IQUUCqm03iD_Vbx': {u'lat': 1.2994299, u'lng': 103.8454878, u'time': 1510017938504}, u'-KyJ1s19nHY47hMCLAQa': {u'lat': 1.3179883, u'lng': 103.8297774, u'time': 1510017302509}, u'-KyIvKRae4SpRtOz-0Tp': {u'lat': 1.389914, u'lng': 103.7551657, u'time': 1510015325325}, u'-KyJ3npspOf8UhfykHQO': {u'lat': 1.2974113, u'lng': 103.8464439, u'time': 1510017809120}, u'-KyIy9Buxy4hsSwx3oSA': {u'lat': 1.3787954, u'lng': 103.7617623, u'time': 1510016066140}, u'-KyIyMHUiwraUCVwjTeP': {u'lat': 1.3799087, u'lng': 103.7609593, u'time': 1510016119746}, u'-KyJ01cfKDaixZqiRjJV': {u'lat': 1.3375854, u'lng': 103.7819632, u'time': 1510016821650}, u'-KyIuG9zfiHVlvvEXIuL': {u'lat': 1.3928772, u'lng': 103.7430874, u'time': 1510015045769}, u'-KyJ56p-VFyfqbkMkp_Z': {u'lat': 1.2982843, u'lng': 103.8446146, u'time': 1510018153663}, u'-KyItCBgIR3GYLdkESmK': {u'lat': 1.3965939, u'lng': 103.7460516, u'time': 1510014767366}, u'-KyIuUEthacRVc17iXCV': {u'lat': 1.3923756, u'lng': 103.7447528, u'time': 1510015103427}, u'-KyIsoWZagC3lS_NmGks': {u'lat': 1.3961948, u'lng': 103.7478282, u'time': 1510014666291}, u'-KyJ0ygML2MvTgTOTWD9': {u'lat': 1.3290015, u'lng': 103.7978994, u'time': 1510017067093}, u'-KyIxjXYY78tmG0fYfjM': {u'lat': 1.3787954, u'lng': 103.7617623, u'time': 1510015956933}, u'-KyIx1yayxViq_ek_tgm': {u'lat': 1.3774775, u'lng': 103.7632868, u'time': 1510015774108}, u'-KyIz5oAgGsa0fENnBL4': {u'lat': 1.3713868, u'lng': 103.7642183, u'time': 1510016314603}, u'-KyJ1ChN_4RomkfwuqRg': {u'lat': 1.3290015, u'lng': 103.7978994, u'time': 1510017128598}, u'-KyJ-Vn_XWC7ACS4Dl6Y': {u'lat': 1.3357322, u'lng': 103.7835771, u'time': 1510016682964}, u'-KyJ0HncU2IaUIt5K7eQ': {u'lat': 1.3375854, u'lng': 103.7819632, u'time': 1510016887888}, u'-KyJ3OZ7Z5BRcWAcOTvx': {u'lat': 1.3026671, u'lng': 103.8482556, u'time': 1510017701488}, u'-KyJ2BhW3SusKzDj64il': {u'lat': 1.3179883, u'lng': 103.8297774, u'time': 1510017387204}}
# 1510016520814 103.7674774 1.3616946
# 1510017938504 103.8454878 1.2994299
# 1510017302509 103.8297774 1.3179883
# 1510015325325 103.7551657 1.389914
# 1510017809120 103.8464439 1.2974113
# 1510016066140 103.7617623 1.3787954
# 1510016119746 103.7609593 1.3799087
# 1510016821650 103.7819632 1.3375854
# 1510015045769 103.7430874 1.3928772
# 1510018153663 103.8446146 1.2982843
# 1510014767366 103.7460516 1.3965939
# 1510015103427 103.7447528 1.3923756
# 1510014666291 103.7478282 1.3961948
# 1510017067093 103.7978994 1.3290015
# 1510015956933 103.7617623 1.3787954
# 1510015774108 103.7632868 1.3774775
# 1510016314603 103.7642183 1.3713868
# 1510017128598 103.7978994 1.3290015
# 1510016682964 103.7835771 1.3357322
# 1510016887888 103.7819632 1.3375854
# 1510017701488 103.8482556 1.3026671
# 1510017387204 103.8297774 1.3179883

# %%
import time
from datetime import date
current_date=date.today()
print current_date
# Out:
# 2017-11-06

# %%
#get lng, lat from firebase display
import time
from datetime import date
from firebase import firebase

current_date=date.today()
# current_date='2017-11-06'
firebase=firebase.FirebaseApplication ('https://ionic2do-ee1d2.firebaseio.com',None)
results=firebase.get("/location_"+str(current_date),None)

z=results.items()
# sort base on time field
z.sort(key=lambda x: (x[1]['time']))

template_line = \
    ''' \
    { "type" : "Feature",
        "geometry" : {
            "type" : "LineString",
            "coordinates" : [[%s, %s],[%s,%s]]},
        "properties" : {}
        },
    '''        
        
template_marker = \
    ''' \
    { "type" : "Feature",
        "geometry" : {
            "type" : "Point",
            "coordinates" : [%s, %s]},
        "properties" : {}
        },
    '''
    
# the head of the geojson file
output = \
    ''' \
{ "type" : "FeatureCollection",
    "features" : [
    '''
i=0
for uid,items in z: 
    i+=1
    print items.get('time'),items.get('lng'),items.get('lat')
    output += template_marker % (items.get('lng'), items.get('lat'))
    try:
        output += template_line % (items.get('lng'), items.get('lat'),z[i][1].get('lng'), z[i][1].get('lat'))
    except:
        print ("expected!!!")
    
# the tail of the geojson file
output += \
    ''' \
    ]
}
    '''
    
outFileHandle = open(str(current_date)+".geojson", "w")
outFileHandle.write(output)
outFileHandle.close()

import mplleaflet
import geopandas as gpd

# admin=gpd.GeoDataFrame.from_file('/Users/tecksoon/ISS/pyCourse/pydot/SingMaps/singapore_admin.geojson')
# 1510049820901 103.8214069 1.2650336
# 1510049878282 103.8214069 1.2650336
# 1510049880920 103.8214069 1.2650336
# 1510049938301 103.8214069 1.2650336
# 1510049940934 103.8214069 1.2650336
# 1510049998325 103.8214069 1.2650336
# 1510050000921 103.8214069 1.2650336
# 1510050058334 103.8044193 1.2724905
# 1510050060945 103.8044193 1.2724905
# 1510050118336 103.8044193 1.2724905
# 1510050120946 103.8044193 1.2724905
# 1510050178350 103.8044193 1.2724905
# 1510050180983 103.8044193 1.2724905
# 1510050238359 103.8044193 1.2724905
# 1510050240988 103.8044193 1.2724905
# 1510050298377 103.8044193 1.2724905
# 1510050300982 103.8044193 1.2724905
# 1510050358441 103.7848606 1.2971689
# 1510050360990 103.7848606 1.2971689
# 1510050430135 103.7848606 1.2971689
# 1510050432725 103.7848606 1.2971689
# 1510050490158 103.7848606 1.2971689
# 1510050492754 103.7848606 1.2971689
# 1510050552052 103.7874912 1.2996736
# 1510050554177 103.7873853 1.2995536
# 1510050612307 103.7871444 1.2984894
# 1510050614200 103.7871636 1.2983452
# 1510050671777 103.7871653 1.2982784
# 1510050672767 103.7871653 1.2982784
# 1510051618614 103.7874206 1.2980338
# 1510051620973 103.7874196 1.2980214
# expected!!!

# %%
import time
from datetime import date
from firebase import firebase

current_date=date.today()
# current_date='2017-11-06'
firebase=firebase.FirebaseApplication ('https://ionic2do-ee1d2.firebaseio.com',None)
results=firebase.get("/location_"+str(current_date),None)
# print results
for uid,items in results.iteritems():
#     print uid,items, items.get('time'), items.get('lng'),item.get('lat')
    print items.get('time'),items.get('lng'),items.get('lat')
    
template = \
    ''' \
    { "type" : "Feature",
        "geometry" : {
            "type" : "Point",
            "coordinates" : [%s, %s]},
        "properties" : {}
        },
    '''
    
# the head of the geojson file
output = \
    ''' \
{ "type" : "FeatureCollection",
    "features" : [
    '''
for uid,items in results.iteritems():    
    output += template % (items.get('lng'), items.get('lat'))
    
# the tail of the geojson file
output += \
    ''' \
    ]
}
    '''
    
outFileHandle = open(str(current_date)+".geojson", "w")
outFileHandle.write(output)
outFileHandle.close()

import mplleaflet
import geopandas as gpd

admin=gpd.GeoDataFrame.from_file('/Users/tecksoon/ISS/pyCourse/pydot/SingMaps/singapore_admin.geojson')
track=gpd.GeoDataFrame.from_file('/Users/tecksoon/ISS/pyCourse/pydot/'+ str(current_date)+'.geojson')

singapore=admin.ix[0]
# roads=roads[roads.geometry.within(singapore.geometry)]
# buildings=buildings[buildings.geometry.within(singapore.geometry)]
track=track[track.geometry.within(singapore.geometry)]

# rx=roads.geometry.plot()
# bx=buildings.geometry.plot()
tr=track.geometry.plot(marker='*', color='red', markersize=200)

# mplleaflet.display(fig=bx.figure) #to display it right at the notebook
# mplleaflet.show(fig=bx.figure) #output as _map.html
# mplleaflet.show(fig=rx.figure)
mplleaflet.show(fig=tr.figure)
# Out:
# 1510050672767 103.7871653 1.2982784
# 1510048859916 103.8452468 1.2998601
# 1510048739477 103.8454813 1.2995961
# 1510049160795 103.8828463 1.338175
# 1510050178350 103.8044193 1.2724905
# 1510050300982 103.8044193 1.2724905
# 1510049460047 103.8212647 1.2654044
# 1510050238359 103.8044193 1.2724905
# 1510018153663 103.8446146 1.2982843
# 1510050298377 103.8044193 1.2724905
# 1510014767366 103.7460516 1.3965939
# 1510015103427 103.7447528 1.3923756
# 1510048980759 103.8828463 1.338175
# 1510050118336 103.8044193 1.2724905
# 1510048619495 103.8452217 1.2985731
# 1510050120946 103.8044193 1.2724905
# 1510051618614 103.7874206 1.2980338
# 1510017128598 103.7978994 1.3290015
# 1510048920120 103.8452468 1.2998601
# 1510049581180 103.8214069 1.2650336
# 1510016887888 103.7819632 1.3375854
# 1510050554177 103.7873853 1.2995536
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:44: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")

filename="bible.txt"
word_dict={}
stop=set(stopwords.words('english'))

# dictionary={}
# for word in inputdata.split():
#     if dictionary.get(word,None):
#         dictionary[word]+=1
#     else:
#         dictionary[word]=1

with open(filename,"r") as f:
    content=f.read()
    content=content.lower()
    words=content.split()
    for each_word in words:
        if each_word in stop:
            continue
        if each_word in word_dict:
            word_dict[each_word]+=1;
        else:
            word_dict[each_word]=1;
print (word_dict)
print (len(word_dict))

from wordcloud import WordCloud
wc=WordCloud()
wc.generate_from_frequencies(frequencies=word_dict)
image=wc.to_image()
image.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/tecksoon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'sending;': 1, 'tubalcain,': 1, 'considered,': 1, 'avites:': 1, 'aijalon': 3, 'hanging': 17, 'zohar,': 3, 'dance:': 2, 'whither,': 1, 'whither.': 2, 'theophilus,': 2, 'slothful': 13, 'wood,': 55, 'wood.': 12, 'jeroboam,': 15, 'wood:': 9, 'wood;': 7, 'bringing': 23, 'shammua,': 2, 'seven;': 3, 'seven:': 2, 'seven?': 1, 'broiled': 1, 'shammua;': 1, 'seven.': 10, 'seven,': 3, '43:19': 3, '43:18': 3, '43:11': 4, '43:10': 4, '43:13': 4, 'gilead.': 22, '43:15': 3, '43:14': 3, '43:17': 3, '43:16': 3, 'consenting': 2, 'oars,': 1, 'scraped': 2, 'gilead;': 2, 'gilead:': 5, 'adullam:': 2, 'adullam;': 1, 'errors': 1, 'rhodes,': 1, 'azotus:': 1, 'nature,': 4, 'senir:': 1, 'kid;': 2, 'jemuel,': 2, 'adullam,': 4, 'kid,': 5, 'kid.': 1, 'senir,': 1, 'titles;': 1, 'crouch': 1, '89:30': 1, 'fire.': 78, 'joel,': 8, '123:3': 1, '123:2': 1, '123:1': 1, 'climbed': 2, 'sighest': 1, 'controversy': 12, 'joel;': 4, 'error.': 2, 'golden': 66, 'speeches;': 1, 'lengthen': 2, 'satest': 2, 'jerusalem?': 10, 'forborn': 1, 'speeches.': 1, 'speeches,': 1, '41:17': 5, '41:16': 5, '41:15': 5, '41:14': 5, '41:13': 6, '41:12': 6, '41:11': 6, '41:10': 6, 'wept.': 15, '41:19': 4, '41:18': 5, 'azaziah:': 1, 'therefore': 1082, 'oft,': 2, '133:1': 1, '133:2': 1, '133:3': 
'harorite,': 1, 'rich': 54, 'plate': 2, 'twenty,)': 1, 'truly:': 1, '6:74': 1, '37:16': 7, '37:17': 7, '37:14': 7, '37:15': 7, '37:12': 7, '37:13': 7, '37:10': 7, 'altogether': 24, 'givest': 12, '37:18': 7, '37:19': 7, 'ithai': 1, 'buyest': 2, 'tychicus,': 2, 'eyelids': 6, 'nature:': 1, 'mammon': 1, 'nature;': 1, 'mattanah:': 1, 'subtilly': 2, 'lamentations,': 1, 'lamentations.': 1, 'philistia': 1, 'lots': 13, 'mibsam,': 2, 'createth': 1, 'dawn,': 1, 're ...
# 32147

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
nltk.download("stopwords")
 
data = "All work and no play makes jack dull boy. All work and no play makes jack a dull boy."
stop = set(stopwords.words('english'))
print(len(stop))
print(stop)
words =data
#words = word_tokenize(data)
wordsFiltered = []
 
for w in words:
    if w not in stop:
        wordsFiltered.append(w)
 
print(wordsFiltered)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/tecksoon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 153
# set([u'all', u'just', u'being', u'over', u'both', u'through', u'yourselves', u'its', u'before', u'o', u'hadn', u'herself', u'll', u'had', u'should', u'to', u'only', u'won', u'under', u'ours', u'has', u'do', u'them', u'his', u'very', u'they', u'not', u'during', u'now', u'him', u'nor', u'd', u'did', u'didn', u'this', u'she', u'each', u'further', u'where', u'few', u'because', u'doing', u'some', u'hasn', u'are', u'our', u'ourselves', u'out', u'what', u'for', u'while', u're', u'does', u'above', u'between', u'mustn', u't', u'be', u'we', u'who', u'were', u'here', u'shouldn', u'hers', u'by', u'on', u'about', u'couldn', u'of', u'against', u's', u'isn', u'or', u'own', u'into', u'yourself', u'down', u'mightn', u'wasn', u'your', u'from', u'her', u'their', u'aren', u'there', u'been', u'whom', u'too', u'wouldn', u'themselves', u'weren', u'was', u'until', u'more', u'himself', u'that', u'but', u'don', u'with', u'than', u'those', u'he', u'me', u'myself', u'ma', u'these', u'up', u'will', u'below', u'ain', u'can', u'theirs', u'my', u'and', u've', u'then', u'is', u'am', u'it', u'doesn', u'an', u'as', u'itself', u'at', u'have', u'in', u'any', u'if', u'again', u'no', u'when', u'same', u'how', u'other', u'which', u'you', u'shan', u'needn', u'haven', u'after', u'most', u'such', u'why', u'a', u'off', u'i', u'm', u'yours', u'so', u'y', u'the', u'having', u'once'])
# ['A', 'l', 'l', ' ', 'w', 'r', 'k', ' ', 'n', ' ', 'n', ' ', 'p', 'l', ' ', 'k', 'e', ' ', 'j', 'c', 'k', ' ', 'u', 'l', 'l', ' ', 'b', '.', ' ', 'A', 'l', 'l', ' ', 'w', 'r', 'k', ' ', 'n', ' ', 'n', ' ', 'p', 'l', ' ', 'k', 'e', ' ', 'j', 'c', 'k', ' ', ' ', 'u', 'l', 'l', ' ', 'b', '.']

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /anaconda2/lib/python2.7/site-packages
# Requirement already satisfied: six in /anaconda2/lib/python2.7/site-packages (from nltk)

# %%
import re
a="$100.10"
print float (a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-740cd3f86ad7> in <module>()
#       1 a="$100.10"
# ----> 2 print float (a)
#
# ValueError: could not convert string to float: $100.10
